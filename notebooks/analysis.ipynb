# %%
import pandas as pd

# %%
df_24 = pd.read_csv(r'../data/raw/srag_datasus_2024.csv', sep=';')
df_24.head()
# Out:
# C:\Users\ferra\AppData\Local\Temp\ipykernel_12320\875338816.py:1: DtypeWarning: Columns (14,59,61,62,63,66,92,94,121,180,181,185,186,188) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_24 = pd.read_csv(r'../data/raw/srag_datasus_2024.csv', sep=';')
#        NU_NOTIFIC  DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI SG_UF_NOT  \
# 0  31699870911712  2024-01-24        4  2024-01-22        4        GO
# 1  31701367675066  2024-04-25       17  2024-04-19       16        DF
# 2  31701948644835  2024-01-09        2  2024-01-08        2        SP
# 3  31702296268583  2024-02-20        8  2024-02-19        8        MG
# 4  31704044720467  2023-12-31        1  2023-12-31        1        SP
#
#                        ID_REGIONA  CO_REGIONA             ID_MUNICIP  \
# 0                         CENTRAL      1779.0                GOIANIA
# 1                             NaN         NaN               BRASILIA
# ...

# %%
df_25 = pd.read_csv(r'../data/raw/srag_datasus_2025.csv', sep=';')
df_25.head()
# Out:
# C:\Users\ferra\AppData\Local\Temp\ipykernel_12320\1755947181.py:1: DtypeWarning: Columns (14,92,94,185,186,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_25 = pd.read_csv(r'../data/raw/srag_datasus_2025.csv', sep=';')
#        NU_NOTIFIC  DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI SG_UF_NOT  \
# 0  31735451969802  2024-12-29        1  2024-12-29        1        SP
# 1  31735516593521  2024-12-29        1  2024-12-29        1        SP
# 2  31735544021940  2024-12-29        1  2024-12-29        1        SP
# 3  31735559043222  2024-12-30        1  2024-12-29        1        AC
# 4  31735560267779  2024-12-30        1  2024-12-29        1        PB
#
#                        ID_REGIONA  CO_REGIONA             ID_MUNICIP  \
# 0        GVE VIII MOGI DAS CRUZES      1333.0              GUARULHOS
# 1        GVE VIII MOGI DAS CRUZES      1333.0              GUARULHOS
# 2  GVE XXIX SAO JOSE DO RIO PRETO      1354.0  SAO JOSE DO RIO PRETO
# ...

# %%
all(df_25.columns == df_24.columns)
# Out:
# True

# %%
df_25.head().to_csv(r'../data/raw/sample_srag_datasus_2025.csv', sep=';', index=False)
